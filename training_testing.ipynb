# %%
# !git clone https://github.com/triton-droids/pupper-simulations.git
# %cd pupper-simulations
# Out:
# fatal: destination path 'pupper-simulations' already exists and is not an empty directory.
# /content/pupper-simulations

# %%
# !pip install -r requirements.txt
# %cd locomotion
# Out:
# Requirement already satisfied: numpy==2.3.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.3.4)
# Requirement already satisfied: mujoco==3.3.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (3.3.4)
# Requirement already satisfied: xacrodoc==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: ml_collections==1.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: jax==0.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: brax==0.13.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.13.0)
# Requirement already satisfied: warp==1.0.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.0.4)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.4->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.4->-r requirements.txt (line 2)) (1.13.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.4->-r requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.4->-r requirements.txt (line 2)) (3.1.10)
# Requirement already satisfied: docutils!=0.21 in /usr/local/lib/python3.12/dist-packages (from xacrodoc==1.3.0->-r requirements.txt (line 3)) (0.21.2)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from xacrodoc==1.3.0->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: rospkg>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from xacrodoc==1.3.0->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: jaxlib<=0.8.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from jax==0.8.0->-r requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax==0.8.0->-r requirements.txt (line 7)) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax==0.8.0->-r requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax==0.8.0->-r requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (0.10.7)
# Requirement already satisfied: jaxopt in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (0.8.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: mujoco-mjx in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (3.3.4)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (0.2.6)
# Requirement already satisfied: orbax-checkpoint>=0.11.22 in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (0.11.28)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (2.6.4)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from brax==0.13.0->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: tensorstore>=0.1.71 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (0.1.78)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (3.20.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax==0.13.0->-r requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: catkin-pkg in /usr/local/lib/python3.12/dist-packages (from rospkg>=1.5.0->xacrodoc==1.3.0->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: distro>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from rospkg>=1.5.0->xacrodoc==1.3.0->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.4->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.4->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.4->-r requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax==0.13.0->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask->brax==0.13.0->-r requirements.txt (line 8)) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax==0.13.0->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->brax==0.13.0->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax==0.13.0->-r requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax->brax==0.13.0->-r requirements.txt (line 8)) (13.9.4)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->brax==0.13.0->-r requirements.txt (line 8)) (0.1.10)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax->brax==0.13.0->-r requirements.txt (line 8)) (0.1.90)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardx->brax==0.13.0->-r requirements.txt (line 8)) (25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->brax==0.13.0->-r requirements.txt (line 8)) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->brax==0.13.0->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->brax==0.13.0->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->brax==0.13.0->-r requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from catkin-pkg->rospkg>=1.5.0->xacrodoc==1.3.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from catkin-pkg->rospkg>=1.5.0->xacrodoc==1.3.0->-r requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->brax==0.13.0->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->catkin-pkg->rospkg>=1.5.0->xacrodoc==1.3.0->-r requirements.txt (line 3)) (1.17.0)
# /content/pupper-simulations/locomotion

# %%
from bittle_env import BittleEnv

from brax import envs
import functools
from brax.training.agents.ppo import networks as ppo_networks
from brax.training.agents.ppo import train as ppo
from brax.io import model

from datetime import datetime
import sys
from etils import epath
from matplotlib import pyplot as plt

from flax.training import orbax_utils
from orbax import checkpoint as ocp
import jax
# Out:
# /usr/local/lib/python3.12/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.7.2 is installed, but it is not compatible with the installed jaxlib version 0.8.0, so it will not be used.
#   warnings.warn(

# %%
def progress(num_steps, metrics):
  times.append(datetime.now())
  x_data.append(num_steps)
  y_data.append(metrics['eval/episode_reward'])
  ydataerr.append(metrics['eval/episode_reward_std'])

  plt.xlim([0, train_fn.keywords['num_timesteps'] * 1.25])
  plt.ylim([min_y, max_y])

  plt.xlabel('# environment steps')
  plt.ylabel('reward per episode')
  plt.title(f'y={y_data[-1]:.3f}')

  plt.errorbar(
      x_data, y_data, yerr=ydataerr)
  plt.show()

def domain_randomize(sys, rng):
  """Randomizes the mjx.Model."""
  @jax.vmap
  def rand(rng):
    _, key = jax.random.split(rng, 2)
    # friction
    friction = jax.random.uniform(key, (1,), minval=0.6, maxval=1.4)
    friction = sys.geom_friction.at[:, 0].set(friction)
    # actuator
    _, key = jax.random.split(key, 2)
    gain_range = (-5, 5)
    param = jax.random.uniform(
        key, (1,), minval=gain_range[0], maxval=gain_range[1]
    ) + sys.actuator_gainprm[:, 0]
    gain = sys.actuator_gainprm.at[:, 0].set(param)
    bias = sys.actuator_biasprm.at[:, 1].set(-param)
    return friction, gain, bias

  friction, gain, bias = rand(rng)

  in_axes = jax.tree_util.tree_map(lambda x: None, sys)
  in_axes = in_axes.tree_replace({
      'geom_friction': 0,
      'actuator_gainprm': 0,
      'actuator_biasprm': 0,
  })

  sys = sys.tree_replace({
      'geom_friction': friction,
      'actuator_gainprm': gain,
      'actuator_biasprm': bias,
  })
  return sys, in_axes

# %%
envs.register_environment('bittle', BittleEnv)

env_name = 'bittle'
xml_path = 'bittle_adapted_scene.xml'
env = envs.get_environment(env_name, xml_path = xml_path)

ckpt_path = epath.Path('/tmp/quadrupred_joystick/ckpts')
ckpt_path.mkdir(parents=True, exist_ok=True)

def policy_params_fn(current_step, make_policy, params):
  # save checkpoints
  orbax_checkpointer = ocp.PyTreeCheckpointer()
  save_args = orbax_utils.save_args_from_target(params)
  path = ckpt_path / f'{current_step}'
  orbax_checkpointer.save(path, params, force=True, save_args=save_args)


make_networks_factory = functools.partial(
    ppo_networks.make_ppo_networks,
        policy_hidden_layer_sizes=(128, 128, 128, 128))
train_fn = functools.partial(
      ppo.train, num_timesteps=100_000_000, num_evals=10,
      reward_scaling=1, episode_length=1000, normalize_observations=True,
      action_repeat=1, unroll_length=20, num_minibatches=32,
      num_updates_per_batch=4, discounting=0.97, learning_rate=3.0e-4,
      entropy_cost=1e-2, num_envs=8192, batch_size=256,
      network_factory=make_networks_factory,
      randomization_fn=domain_randomize,
      policy_params_fn=policy_params_fn,
      seed=0)

x_data = []
y_data = []
ydataerr = []
times = [datetime.now()]
max_y, min_y = 40, 0

# Reset environments since internals may be overwritten by tracers from the
# domain randomization function.
env = envs.get_environment(env_name, xml_path = xml_path)
eval_env = envs.get_environment(env_name, xml_path = xml_path)
make_inference_fn, params, _= train_fn(environment=env,
                                       progress_fn=progress,
                                       eval_env=eval_env)

print(f'time to jit: {times[1] - times[0]}')
print(f'time to train: {times[-1] - times[1]}')

# Save and reload params.
model_path = '/tmp/mjx_brax_quadruped_policy'
model.save_params(model_path, params)
params = model.load_params(model_path)

inference_fn = make_inference_fn(params)
jit_inference_fn = jax.jit(inference_fn)
# Out:
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servo_rfs_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servo_rrs__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_neck__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screw_6_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servo_lfs_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servo_lrs__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "a_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "b__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "d_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "e_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "f_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "g_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "h__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "i_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "j__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "k_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "l_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "logo_5_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "logo_1_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "logo_2_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "logo_3_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "logo_4_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "battery_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_thrf__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_thorf_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_3_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_4_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servos_rf_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "shank_rf_1_convex" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_thrr_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_thorr_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_1_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_2_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servos_rr_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "shank_rr_1_convex" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servo_neck__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "jaw_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_thlf_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_tholf_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_6_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_5_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servos_lf_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "shank_lf_1_convex" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_thlr_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "c_tholr__1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_8_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "screwm_7_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "servos_lr_1" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/mujoco/mjx/_src/mesh.py:141: UserWarning: Mesh "shank_lr_1_convex" has a coplanar face with more than 20 vertices. This may lead to performance issues and inaccuracies in collision detection. Consider decimating the mesh.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Bittle has 9 actuators
# Bittle has 9 position DOFs
# Bittle has 9 velocity DOFs
# Found lower leg body: servos_rf_1 (id=2)
# Found lower leg body: servos_rr_1 (id=4)
# Found lower leg body: servos_lf_1 (id=7)
# Found lower leg body: servos_lr_1 (id=9)
# Bittle has 9 actuators
# Bittle has 9 position DOFs
# Bittle has 9 velocity DOFs
# Found lower leg body: servos_rf_1 (id=2)
# Found lower leg body: servos_rr_1 (id=4)
# Found lower leg body: servos_lf_1 (id=7)
# Found lower leg body: servos_lr_1 (id=9)
# Bittle has 9 actuators
# Bittle has 9 position DOFs
# Bittle has 9 velocity DOFs
# Found lower leg body: servos_rf_1 (id=2)
# Found lower leg body: servos_rr_1 (id=4)
# Found lower leg body: servos_lf_1 (id=7)
# Found lower leg body: servos_lr_1 (id=9)
# /usr/local/lib/python3.12/dist-packages/jax/_src/abstract_arrays.py:135: RuntimeWarning: overflow encountered in cast
#   return literals.TypedNdArray(np.asarray(x, dtype), weak_type=False)
# Exception ignored in: <function _xla_gc_callback at 0x7e1712463880>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/jax/_src/lib/__init__.py", line 129, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
